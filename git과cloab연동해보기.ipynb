# %%
# !dir
# Out:
# drive  sample_data

# %%
cd drive/MyDrive/Kaggle
# Out:
# /content/drive/MyDrive/Kaggle

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Kaggle/.git/

# %%
# !dir
# Out:
# git과cloab연동해보기.ipynb

# %%
# !git add git과cloab연동해보기.ipynb

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   "git\341\204\200\341\205\252cloab\341\204\213\341\205\247\341\206\253\341\204\203\341\205\251\341\206\274\341\204\222\341\205\242\341\204\207\341\205\251\341\204\200\341\205\265.ipynb"

# %%
# !git config --global user.email "rockervb@gmail.com"
# !git config --global user.name "actuary84"

# %%
# !git commit -m 'git과 google colab 연동 테스트'
# Out:
# [master 8ae6c97] git과 google colab 연동 테스트
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push
# Out:
# fatal: No configured push destination.
# Either specify the URL from the command-line or configure a remote repository using
#
#     git remote add <name> <url>
#
# and then push using the remote name
#
#     git push <name>
